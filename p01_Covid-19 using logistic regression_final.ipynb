# %%
# Import required libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# Keras specific
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
pd.set_option('display.max_columns',None)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
df_train = pd.read_excel("Train_dataset.xlsx")
df_to_predict = pd.read_excel("Test_dataset.xlsx")

# %%
df_train.head()
# Out:
#    people_ID        Region  Gender Designation             Name Married  \
# 0          1  Bhubaneshwar  Female         Mrs            mansi     YES
# 1          2  Bhubaneshwar  Female         Mrs        riya masi     YES
# 2          3  Bhubaneshwar  Female         Mrs           sunita      NO
# 3          4  Bhubaneshwar  Female         Mrs   anjali @ babli     YES
# 4          5  Bhubaneshwar  Female         Mrs  champa karketta      NO
#
#    Children     Occupation Mode_transport  cases/1M  Deaths/1M  \
# 0       1.0         Farmer         Public         2          0
# 1       2.0         Farmer           Walk         2          0
# 2       1.0        Cleaner         Public         2          0
# 3       1.0         Driver            Car         2          0
# 4       2.0  Manufacturing            Car         2          0
#
#               comorbidity  Age  Coma score Pulmonary score  \
# 0            Hypertension   68           8            <400
# 1                Diabetes   64          15            <100
# 2                    None   19          13            <300
# 3  Coronary Heart Disease   33           9            <200
# 4                Diabetes   23           7            <400
#
#   cardiological pressure  Diuresis  Platelets    HBB  d-dimer  Heart rate  \
# 0                 Normal     441.0      154.0   93.0    233.0        82.0
# 1               Stage-02       NaN      121.0   56.0    328.0        89.0
# 2               Elevated     416.0      124.0  137.0    213.0        77.0
# 3               Stage-01     410.0       98.0  167.0    275.0        64.0
# 4                 Normal     390.0       21.0  153.0    331.0        71.0
#
#    HDL cholesterol  Charlson Index  Blood Glucose  Insurance   salary  \
# 0             58.0              27              7  3600000.0  1300000
# 1             68.0               5              6  1600000.0   400000
# 2             43.0              40              6  3400000.0   900000
# 3             60.0              27              7   700000.0  2300000
# 4             64.0              32              7  3200000.0  1100000
#
#    FT/month  Infect_Prob
# 0       2.0    49.135010
# 1       1.0    51.147880
# 2       1.0    73.224000
# 3       1.0    48.779225
# 4       1.0    87.868800

# %%
df.shape
# Out:
# (10714, 9)

# %%
df_train.head()
# Out:
#    people_ID        Region  Gender Designation             Name Married  \
# 0          1  Bhubaneshwar  Female         Mrs            mansi     YES
# 1          2  Bhubaneshwar  Female         Mrs        riya masi     YES
# 2          3  Bhubaneshwar  Female         Mrs           sunita      NO
# 3          4  Bhubaneshwar  Female         Mrs   anjali @ babli     YES
# 4          5  Bhubaneshwar  Female         Mrs  champa karketta      NO
#
#    Children     Occupation Mode_transport  cases/1M  Deaths/1M  \
# 0       1.0         Farmer         Public         2          0
# 1       2.0         Farmer           Walk         2          0
# 2       1.0        Cleaner         Public         2          0
# 3       1.0         Driver            Car         2          0
# 4       2.0  Manufacturing            Car         2          0
#
#               comorbidity  Age  Coma score Pulmonary score  \
# 0            Hypertension   68           8            <400
# 1                Diabetes   64          15            <100
# 2                    None   19          13            <300
# 3  Coronary Heart Disease   33           9            <200
# 4                Diabetes   23           7            <400
#
#   cardiological pressure  Diuresis  Platelets    HBB  d-dimer  Heart rate  \
# 0                 Normal     441.0      154.0   93.0    233.0        82.0
# 1               Stage-02       NaN      121.0   56.0    328.0        89.0
# 2               Elevated     416.0      124.0  137.0    213.0        77.0
# 3               Stage-01     410.0       98.0  167.0    275.0        64.0
# 4                 Normal     390.0       21.0  153.0    331.0        71.0
#
#    HDL cholesterol  Charlson Index  Blood Glucose  Insurance   salary  \
# 0             58.0              27              7  3600000.0  1300000
# 1             68.0               5              6  1600000.0   400000
# 2             43.0              40              6  3400000.0   900000
# 3             60.0              27              7   700000.0  2300000
# 4             64.0              32              7  3200000.0  1100000
#
#    FT/month  Infect_Prob
# 0       2.0    49.135010
# 1       1.0    51.147880
# 2       1.0    73.224000
# 3       1.0    48.779225
# 4       1.0    87.868800

# %%
# we have to Check for null values in the dataset
df_train.isnull().sum()
# Out:
# people_ID                    0
# Region                       0
# Gender                       0
# Designation                  0
# Name                        20
# Married                      0
# Children                   311
# Occupation                 747
# Mode_transport               3
# cases/1M                     0
# Deaths/1M                    0
# comorbidity                226
# Age                          0
# Coma score                   0
# Pulmonary score              0
# cardiological pressure      97
# Diuresis                   716
# Platelets                  924
# HBB                         16
# d-dimer                   1114
# Heart rate                1114
# HDL cholesterol             35
# Charlson Index               0
# Blood Glucose                0
# Insurance                 1090
# salary                       0
# FT/month                   723
# Infect_Prob                  0
# dtype: int64

# %%
print("Number of rows in training dataset",df_train.shape)
print("Number of rows in prediction dataset",df_to_predict.shape)
# Out:
# Number of rows in training dataset (10714, 28)
# Number of rows in prediction dataset (14498, 27)

# %%
# noe lets check null column values
null_columns=df_train.columns[df_train.isnull().any()]
print(df_train[df_train.isnull().any(axis=1)][null_columns].head())
# Out:
#                Name  Children     Occupation Mode_transport  \
# 1         riya masi       2.0         Farmer           Walk
# 6              iqra       2.0  Manufacturing            Car
# 8     kalyani patro       2.0          Sales         Public
# 12  karina @ kavita       NaN            NaN         Public
# 14         subhadra       2.0  Manufacturing         Public
#
#                comorbidity cardiological pressure  Diuresis  Platelets    HBB  \
# 1                 Diabetes               Stage-02       NaN      121.0   56.0
# 6   Coronary Heart Disease                 Normal       NaN       75.0  156.0
# 8             Hypertension               Stage-01     310.0        NaN  156.0
# 12                Diabetes               Stage-01     403.0       39.0  174.0
# 14  Coronary Heart Disease               Stage-01     382.0        NaN   24.0
#
#     d-dimer  Heart rate  HDL cholesterol  Insurance  FT/month
# 1     328.0        89.0             68.0  1600000.0       1.0
# 6     311.0        99.0             68.0  4000000.0       1.0
# 8       NaN         NaN             37.0  4500000.0       0.0
# 12    213.0        98.0             43.0        NaN       2.0
# 14      NaN         NaN             38.0  2500000.0       1.0

# %%
# hey now drop null column values
df_train.dropna(inplace=True)

# %%
# we are going to select duplicate rows except first occurrence based on all columns
duplicateRowsDF = df_train[df_train.duplicated()]
print("Total Duplicate Rows except first occurrence based on all columns are :")
duplicateRowsDF.shape
# Out:
# Total Duplicate Rows except first occurrence based on all columns are :
# (0, 28)

# %%
df_train.isnull().sum()
# Out:
# people_ID                 0
# Region                    0
# Gender                    0
# Designation               0
# Name                      0
# Married                   0
# Children                  0
# Occupation                0
# Mode_transport            0
# cases/1M                  0
# Deaths/1M                 0
# comorbidity               0
# Age                       0
# Coma score                0
# Pulmonary score           0
# cardiological pressure    0
# Diuresis                  0
# Platelets                 0
# HBB                       0
# d-dimer                   0
# Heart rate                0
# HDL cholesterol           0
# Charlson Index            0
# Blood Glucose             0
# Insurance                 0
# salary                    0
# FT/month                  0
# Infect_Prob               0
# dtype: int64

# %%
# now clerly remove duplicate rows in training dataset
df_train.drop_duplicates(keep='first',inplace=True)

# %%
# lets See values in columns of dataset 
df_to_predict.head()
# Out:
#    people_ID Region  Gender Designation                Name Married  Children  \
# 0       5942  Delhi  Female         Mrs  smt rekha prajapat     YES         2
# 1      18664  Delhi    Male          Mr              nirmal     YES         2
# 2       5603  Delhi  Female         Mrs               pinky     YES         2
# 3       5649  Delhi  Female         Mrs       pooja @aafrin     YES         2
# 4       5099  Delhi  Female         Mrs              anjali     YES         2
#
#   Occupation Mode_transport  cases/1M  Deaths/1M comorbidity  Age  Coma score  \
# 0     Driver         Public         4          1    Diabetes   52           3
# 1      Legal           Walk         4          1    Diabetes   53          11
# 2      Sales            Car         4          1    Diabetes   35           9
# 3      Sales            Car         4          1        None   31          12
# 4   Business            Car         4          1    Diabetes   51           6
#
#   Pulmonary score cardiological pressure  Diuresis  Platelets  HBB  d-dimer  \
# 0            <200               Stage-01       388        153  196      240
# 1            <200               Stage-01       409         95  138      241
# 2            <100               Stage-02       440         40  166      236
# 3            <300               Elevated       206         78   83      211
# 4            <200               Stage-01       229        109  207      312
#
#    Heart rate  HDL cholesterol  Charlson Index  Blood Glucose  Insurance  \
# 0          85               53              17              3    3900000
# 1          81               61               2              5    1800000
# 2          88               47              24              3    5000000
# 3          87               52              13              6    3100000
# 4          94               68              39              5    2300000
#
#     salary  FT/month
# 0  1300000         1
# 1  1300000         1
# 2  2000000         2
# 3   600000         2
# 4  1500000         1

# %%
pd.set_option('display.max_columns',None)
df_train.head()
# Out:
#    people_ID        Region  Gender Designation             Name Married  \
# 0          1  Bhubaneshwar  Female         Mrs            mansi     YES
# 2          3  Bhubaneshwar  Female         Mrs           sunita      NO
# 3          4  Bhubaneshwar  Female         Mrs   anjali @ babli     YES
# 4          5  Bhubaneshwar  Female         Mrs  champa karketta      NO
# 5          6  Bhubaneshwar  Female         Mrs          sandhya     YES
#
#    Children     Occupation Mode_transport  cases/1M  Deaths/1M  \
# 0       1.0         Farmer         Public         2          0
# 2       1.0        Cleaner         Public         2          0
# 3       1.0         Driver            Car         2          0
# 4       2.0  Manufacturing            Car         2          0
# 5       1.0          Clerk         Public         2          0
#
#               comorbidity  Age  Coma score Pulmonary score  \
# 0            Hypertension   68           8            <400
# 2                    None   19          13            <300
# 3  Coronary Heart Disease   33           9            <200
# 4                Diabetes   23           7            <400
# 5                    None   35           9            <100
#
#   cardiological pressure  Diuresis  Platelets    HBB  d-dimer  Heart rate  \
# 0                 Normal     441.0      154.0   93.0    233.0        82.0
# 2               Elevated     416.0      124.0  137.0    213.0        77.0
# 3               Stage-01     410.0       98.0  167.0    275.0        64.0
# 4                 Normal     390.0       21.0  153.0    331.0        71.0
# 5               Stage-02     389.0      139.0   86.0    216.0        94.0
#
#    HDL cholesterol  Charlson Index  Blood Glucose  Insurance   salary  \
# 0             58.0              27              7  3600000.0  1300000
# 2             43.0              40              6  3400000.0   900000
# 3             60.0              27              7   700000.0  2300000
# 4             64.0              32              7  3200000.0  1100000
# 5             38.0               5              5  4600000.0  1900000
#
#    FT/month  Infect_Prob
# 0       2.0    49.135010
# 2       1.0    73.224000
# 3       1.0    48.779225
# 4       1.0    87.868800
# 5       2.0    49.518345

# %% [markdown]
# # cleaning

# %%
df_to_predict["Designation"].value_counts()
# Out:
# 0    7392
# 1    7106
# Name: Designation, dtype: int64

# %%
df_train.Designation.replace(['Mr','Mrs'], [0,1], inplace=True)
df_to_predict.Designation.replace(['Mr','Mrs'], [0,1], inplace=True)
df_train["Designation"] = df_train["Designation"].astype(int)
df_to_predict["Designation"] = df_to_predict["Designation"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-87171be658f8> in <module>()
# ----> 1 df_train.Designation.replace(['Mr','Mrs'], [0,1], inplace=True)
#       2 df_to_predict.Designation.replace(['Mr','Mrs'], [0,1], inplace=True)
#       3 df_train["Designation"] = df_train["Designation"].astype(int)
#       4 df_to_predict["Designation"] = df_to_predict["Designation"].astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    3427         return super(Series, self).replace(to_replace=to_replace, value=value,
#    3428                                            inplace=inplace, limit=limit,
# -> 3429                                            regex=regex, method=method)
#    3430
#    3431     @Appender(generic._shared_docs['shift'] % _shared_doc_kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    5845                                                        dest_list=value,
#    5846                                                        inplace=inplace,
# -> 5847                                                        regex=regex)
#    5848
#    5849                 else:  # [NA, ''] -> 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in replace_list(self, src_list, dest_list, inplace, regex, mgr)
#    3737             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3738
# -> 3739         masks = [comp(s) for i, s in enumerate(src_list)]
#    3740
#    3741         result_blocks = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in <listcomp>(.0)
#    3737             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3738
# -> 3739         masks = [comp(s) for i, s in enumerate(src_list)]
#    3740
#    3741         result_blocks = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in comp(s)
#    3735             if isna(s):
#    3736                 return isna(values)
# -> 3737             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3738
#    3739         masks = [comp(s) for i, s in enumerate(src_list)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _maybe_compare(a, b, op)
#    5163         raise TypeError(
#    5164             "Cannot compare types {a!r} and {b!r}".format(a=type_names[0],
# -> 5165                                                           b=type_names[1]))
#    5166     return result
#    5167
#
# TypeError: Cannot compare types 'ndarray(dtype=int32)' and 'str'

# %%
df_train["Designation"].value_counts()
# Out:
# 1    3402
# 0    3375
# Name: Designation, dtype: int64

# %%
df_to_predict["Gender"].value_counts()
# Out:
# Male      7392
# Female    7106
# Name: Gender, dtype: int64

# %%
df_train.Gender.replace(['Male','Female'], [0,1], inplace=True)
df_to_predict.Gender.replace(['Male','Female'], [0,1], inplace=True)
df_train["Gender"] = df_train["Gender"].astype(int)
df_to_predict["Gender"] = df_to_predict["Gender"].astype(int)

# %%
df_train["Gender"].value_counts()
# Out:
# 1    3402
# 0    3375
# Name: Gender, dtype: int64

# %%
df_to_predict["Married"].value_counts()
# Out:
# YES    11487
# NO      3011
# Name: Married, dtype: int64

# %%
df_train.Married.replace(['YES','NO'], [1,0], inplace=True)
df_to_predict.Married.replace(['YES','NO'], [1,0], inplace=True)
df_train["Married"] = df_train["Married"].astype(int)
df_to_predict["Married"] = df_to_predict["Married"].astype(int)

# %%
df_train["Married"].value_counts()
# Out:
# 1    5260
# 0    1517
# Name: Married, dtype: int64

# %%
df_to_predict["Occupation"].value_counts()
# Out:
# Researcher       1705
# Sales            1638
# Driver           1621
# Clerk            1620
# Business         1611
# Farmer           1591
# Cleaner          1586
# Manufacturing    1563
# Legal            1563
# Name: Occupation, dtype: int64

# %%
df_train.Occupation.replace(['Legal','Farmer','Researcher','Manufacturing','Cleaner','Driver','Sales','Clerk','Business'], [7,5,0,8,6,2,1,3,4], inplace=True)
df_to_predict.Occupation.replace(['Researcher','Sales','Driver','Clerk','Business','Farmer','Cleaner','Legal','Manufacturing'], [0,1,2,3,4,5,6,7,8], inplace=True)
df_train["Occupation"] = df_train["Occupation"].astype(int)
df_to_predict["Occupation"] = df_to_predict["Occupation"].astype(int)

# %%
df_train["Occupation"].value_counts()
# Out:
# 7    795
# 5    786
# 0    772
# 8    769
# 6    751
# 2    738
# 1    732
# 3    721
# 4    713
# Name: Occupation, dtype: int64

# %%
df_to_predict["Region"].value_counts()
# Out:
# Pune                  2503
# Thiruvananthapuram    2502
# Kolkata               2483
# Mumbai                2475
# Hyderabad             2457
# Delhi                 2078
# Name: Region, dtype: int64

# %%
df_train.Region.replace(['Bengaluru','Chandigarh','Bhubaneshwar','Chennai','Delhi'], [0,1,2,3,4], inplace=True)
df_to_predict.Region.replace(['Pune','Thiruvananthapuram','Kolkata','Mumbai','Hyderabad','Delhi'], [5,6,7,8,9,0], inplace=True)
df_train["Region"] = df_train["Region"].astype(int)
df_to_predict["Region"] = df_to_predict["Region"].astype(int)

# %%
df_train["Region"].value_counts()
# Out:
# 0    1661
# 1    1658
# 2    1627
# 3    1606
# 4     225
# Name: Region, dtype: int64

# %%
df_to_predict["Mode_transport"].value_counts()
# Out:
# Car       4880
# Walk      4834
# Public    4784
# Name: Mode_transport, dtype: int64

# %%
df_train.Mode_transport.replace(['Walk','Public','Car'], [1,2,0], inplace=True)
df_to_predict.Mode_transport.replace(['Car','Walk','Public'], [0,1,2], inplace=True)
df_train["Mode_transport"] = df_train["Mode_transport"].astype(int)
df_to_predict["Mode_transport"] = df_to_predict["Mode_transport"].astype(int)

# %%
df_train["Mode_transport"].value_counts()
# Out:
# 1    2338
# 2    2229
# 0    2210
# Name: Mode_transport, dtype: int64

# %%
df_train=df_train.drop(['Name',"people_ID",'comorbidity','cardiological pressure',],axis=1)
df_to_predict=df_to_predict.drop(['Name',"people_ID",'comorbidity','cardiological pressure'],axis=1)

# %%
df_train
# Out:
#        Region  Gender  Designation  Married  Children  Occupation  \
# 0           2       1            1        1       1.0           5
# 2           2       1            1        0       1.0           6
# 3           2       1            1        1       1.0           2
# 4           2       1            1        0       2.0           8
# 5           2       1            1        1       1.0           3
# 7           2       1            1        1       1.0           8
# 9           2       1            1        1       1.0           5
# 10          2       1            1        1       1.0           8
# 11          2       1            1        1       0.0           2
# 13          2       1            1        1       2.0           4
# 15          2       1            1        1       1.0           5
# 16          2       1            1        1       2.0           1
# 17          2       1            1        1       0.0           0
# 18          2       1            1        1       1.0           3
# 19          2       1            1        1       2.0           0
# 22          2       1            1        0       2.0           2
# 23          2       1            1        1       1.0           6
# 24          2       1            1        0       2.0           3
# 25          2       1            1        1       0.0           5
# 26          2       1            1        1       2.0           8
# 27          2       1            1        1       1.0           8
# 29          2       1            1        1       1.0           8
# 32          2       1            1        1       2.0           7
# 36          2       1            1        1       2.0           4
# 38          2       1            1        1       0.0           5
# 40          2       1            1        1       0.0           4
# 42          2       1            1        1       0.0           0
# 48          2       1            1        1       1.0           7
# 50          2       1            1        1       0.0           8
# 52          2       1            1        1       0.0           1
# ...       ...     ...          ...      ...       ...         ...
# 10672       0       0            0        1       2.0           3
# 10674       0       0            0        0       2.0           7
# 10675       0       0            0        1       1.0           3
# 10676       0       0            0        1       0.0           5
# 10677       0       0            0        1       1.0           5
# 10678       0       0            0        1       0.0           2
# 10679       0       0            0        1       1.0           7
# 10680       0       0            0        1       1.0           4
# 10681       0       0            0        1       1.0           5
# 10682       0       0            0        1       1.0           5
# 10683       0       0            0        1       1.0           6
# 10684       0       0            0        1       0.0           8
# 10685       0       0            0        1       2.0           5
# 10689       0       0            0        1       1.0           2
# 10691       0       0            0        1       1.0           4
# 10693       0       0            0        0       2.0           6
# 10694       0       0            0        1       0.0           1
# 10695       0       0            0        1       0.0           5
# 10696       0       0            0        1       1.0           6
# 10698       0       0            0        0       1.0           5
# 10700       0       0            0        1       1.0           3
# 10701       0       0            0        1       0.0           7
# 10702       0       0            0        1       1.0           8
# 10703       0       0            0        1       2.0           7
# 10704       0       0            0        1       2.0           0
# 10708       0       0            0        1       1.0           5
# 10709       0       0            0        0       2.0           4
# 10711       0       0            0        1       0.0           3
# 10712       0       0            0        1       1.0           7
# 10713       0       0            0        0       2.0           4
#
#        Mode_transport  cases/1M  Deaths/1M  Age  Coma score Pulmonary score  \
# 0                   2         2          0   68           8            <400
# 2                   2         2          0   19          13            <300
# 3                   0         2          0   33           9            <200
# 4                   0         2          0   23           7            <400
# 5                   2         2          0   35           9            <100
# 7                   2         2          0   49          10            <200
# 9                   2         2          0   41          14            <300
# 10                  2         2          0   43           9            <100
# 11                  0         2          0   52           5            <100
# 13                  2         2          0   52          14            <300
# 15                  1         2          0   68          11            <300
# 16                  2         2          0   55          11            <300
# 17                  1         2          0   53           3            <300
# 18                  2         2          0   65           9            <400
# 19                  2         2          0   50           6            <400
# 22                  2         2          0   18           7            <300
# 23                  0         2          0   31           5            <200
# 24                  0         2          0   20           6            <200
# 25                  2         2          0   51          15            <200
# 26                  2         2          0   53          15            <200
# 27                  2         2          0   42          15            <200
# 29                  0         2          0   48           3            <100
# 32                  2         2          0   52           5            <300
# 36                  2         2          0   52          15            <400
# 38                  1         2          0   50           6            <100
# 40                  2         2          0   55          15            <100
# 42                  0         2          0   58           3            <100
# 48                  1         2          0   43          10            <400
# 50                  1         2          0   50           6            <200
# 52                  0         2          0   60           5            <300
# ...               ...       ...        ...  ...         ...             ...
# 10672               1         8          2   52           3            <100
# 10674               0         8          2   19           4            <100
# 10675               0         8          2   63           6            <200
# 10676               0         8          2   47           9            <100
# 10677               0         8          2   30          13            <200
# 10678               1         8          2   55           3            <400
# 10679               0         8          2   52          15            <100
# 10680               0         8          2   37          11            <300
# 10681               0         8          2   57          14            <100
# 10682               1         8          2   59           3            <300
# 10683               2         8          2   62           9            <200
# 10684               1         8          2   54           5            <400
# 10685               0         8          2   30          10            <100
# 10689               0         8          2   61          13            <400
# 10691               2         8          2   65           5            <300
# 10693               2         8          2   19           4            <200
# 10694               1         8          2   47           6            <300
# 10695               1         8          2   58           3            <200
# 10696               1         8          2   31          15            <400
# 10698               0         8          2   21           8            <200
# 10700               1         8          2   36           4            <100
# 10701               2         8          2   50          12            <100
# 10702               0         8          2   67           8            <100
# 10703               2         8          2   28          13            <300
# 10704               1         8          2   28           9            <200
# 10708               2         8          2   35          11            <200
# 10709               0         8          2   20          14            <400
# 10711               2         8          2   59           3            <100
# 10712               1         8          2   49           6            <300
# 10713               0         8          2   17           7            <400
#
#        Diuresis  Platelets    HBB  d-dimer  Heart rate  HDL cholesterol  \
# 0         441.0      154.0   93.0    233.0        82.0             58.0
# 2         416.0      124.0  137.0    213.0        77.0             43.0
# 3         410.0       98.0  167.0    275.0        64.0             60.0
# 4         390.0       21.0  153.0    331.0        71.0             64.0
# 5         389.0      139.0   86.0    216.0        94.0             38.0
# 7         194.0      123.0  179.0    242.0        82.0             59.0
# 9         242.0       23.0  178.0    277.0        83.0             58.0
# 10        373.0       32.0   24.0    203.0        62.0             51.0
# 11        192.0       30.0   66.0    224.0        54.0             68.0
# 13        120.0       17.0   48.0    333.0        99.0             51.0
# 15        239.0       48.0   66.0    348.0        94.0             56.0
# 16        199.0      150.0  113.0    306.0        53.0             43.0
# 17        182.0      123.0  173.0    349.0        74.0             63.0
# 18        181.0       80.0  177.0    287.0        52.0             66.0
# 19        220.0       89.0  170.0    239.0        57.0             41.0
# 22        415.0      133.0  194.0    215.0        88.0             50.0
# 23        203.0       25.0  158.0    342.0        97.0             61.0
# 24        148.0       58.0  204.0    217.0        79.0             37.0
# 25        381.0      158.0   96.0    291.0        95.0             67.0
# 26        251.0      139.0  176.0    277.0        61.0             59.0
# 27        185.0       70.0  190.0    339.0        84.0             48.0
# 29        405.0      156.0  176.0    284.0        76.0             59.0
# 32        315.0      123.0   51.0    238.0        97.0             44.0
# 36        200.0      160.0   53.0    349.0        98.0             64.0
# 38        189.0      114.0   60.0    228.0        98.0             66.0
# 40        364.0       92.0   63.0    289.0        93.0             67.0
# 42        346.0      127.0   58.0    283.0        90.0             63.0
# 48        122.0       66.0   44.0    268.0        50.0             57.0
# 50        226.0       18.0   43.0    300.0        70.0             63.0
# 52        416.0      130.0  175.0    324.0        54.0             48.0
# ...         ...        ...    ...      ...         ...              ...
# 10672     225.0       25.0  180.0    269.0        97.0             50.0
# 10674     436.0      134.0  197.0    311.0        84.0             41.0
# 10675     301.0       18.0   89.0    296.0        84.0             63.0
# 10676     149.0      134.0  162.0    341.0        94.0             61.0
# 10677     426.0      102.0  123.0    311.0        65.0             47.0
# 10678     268.0      117.0   38.0    247.0        65.0             41.0
# 10679     165.0       99.0  150.0    263.0        57.0             57.0
# 10680     176.0       63.0  138.0    227.0        93.0             54.0
# 10681     178.0       72.0   96.0    323.0        82.0             51.0
# 10682     250.0       56.0   31.0    254.0        63.0             69.0
# 10683     189.0      118.0  118.0    328.0        51.0             58.0
# 10684     411.0       97.0  101.0    226.0        61.0             43.0
# 10685     124.0      123.0  111.0    317.0        90.0             36.0
# 10689     388.0       99.0  194.0    343.0        80.0             63.0
# 10691     418.0       18.0   38.0    226.0        79.0             49.0
# 10693     159.0      115.0  117.0    328.0        82.0             59.0
# 10694     431.0       19.0  161.0    259.0        55.0             54.0
# 10695     248.0      115.0   43.0    258.0        93.0             50.0
# 10696     145.0       45.0  121.0    342.0        66.0             63.0
# 10698     372.0       86.0  154.0    268.0        84.0             35.0
# 10700     379.0       50.0  134.0    343.0        78.0             54.0
# 10701     256.0       42.0   55.0    274.0        96.0             40.0
# 10702     417.0       90.0   92.0    234.0        76.0             44.0
# 10703     389.0      121.0   93.0    205.0        67.0             67.0
# 10704     339.0      146.0   72.0    307.0        60.0             58.0
# 10708     397.0       78.0  150.0    337.0        69.0             44.0
# 10709     134.0       67.0   24.0    209.0        61.0             56.0
# 10711     177.0      111.0  151.0    296.0        87.0             37.0
# 10712     352.0      140.0  110.0    253.0        56.0             70.0
# 10713     181.0       65.0  134.0    201.0        82.0             60.0
#
#        Charlson Index  Blood Glucose  Insurance   salary  FT/month  \
# 0                  27              7  3600000.0  1300000       2.0
# 2                  40              6  3400000.0   900000       1.0
# 3                  27              7   700000.0  2300000       1.0
# 4                  32              7  3200000.0  1100000       1.0
# 5                   5              5  4600000.0  1900000       2.0
# 7                  34              3  4100000.0  1200000       0.0
# 9                  28              4  2200000.0  1400000       2.0
# 10                 31              4  4200000.0  1100000       0.0
# 11                 14              5  1000000.0   300000       0.0
# 13                 31              5  3500000.0  2200000       2.0
# 15                 15              3  5000000.0  2200000       1.0
# 16                 17              6  4700000.0  1200000       0.0
# 17                 29              6   300000.0  1700000       1.0
# 18                 37              4  3900000.0  2300000       0.0
# 19                 25              4  1300000.0   800000       0.0
# 22                 33              5  4100000.0  1700000       0.0
# 23                 22              3  3700000.0  1600000       0.0
# 24                  5              4  4100000.0  1000000       0.0
# 25                 39              6  3100000.0  2000000       2.0
# 26                 32              7  4500000.0   700000       1.0
# 27                  2              5  2900000.0  2000000       0.0
# 29                  0              6   800000.0  1400000       1.0
# 32                 26              3  3600000.0   800000       2.0
# 36                 16              6  4000000.0  1800000       2.0
# 38                 40              7  4300000.0  1400000       1.0
# 40                 29              6   700000.0  1400000       1.0
# 42                 30              4  4300000.0  1600000       2.0
# 48                 15              4   300000.0  2000000       1.0
# 50                 16              3  1700000.0   600000       1.0
# 52                 36              4  3400000.0  1800000       1.0
# ...               ...            ...        ...      ...       ...
# 10672               2              5   900000.0  2000000       0.0
# 10674               1              4  4900000.0   900000       1.0
# 10675               7              4   700000.0  2100000       0.0
# 10676              37              5   700000.0  1300000       2.0
# 10677              25              4   600000.0  2200000       1.0
# 10678               0              3  3200000.0   400000       0.0
# 10679              34              3  1700000.0  1800000       1.0
# 10680               8              3  1200000.0  2300000       1.0
# 10681              25              6  1100000.0  2100000       1.0
# 10682              31              4  4300000.0  1300000       0.0
# 10683              12              3  2500000.0  2300000       1.0
# 10684              31              3  4500000.0  1500000       0.0
# 10685              29              5  3200000.0   800000       1.0
# 10689              10              7  2800000.0  1800000       2.0
# 10691              13              4  4800000.0  2000000       2.0
# 10693              23              5  3400000.0  1900000       0.0
# 10694              37              5  4300000.0   700000       2.0
# 10695              13              3  1000000.0   500000       1.0
# 10696              37              6  2300000.0  1500000       2.0
# 10698               2              4  2200000.0  1300000       0.0
# 10700              24              6  1400000.0  1000000       0.0
# 10701              37              6   700000.0   300000       2.0
# 10702              31              7   300000.0  1800000       2.0
# 10703               6              7  3600000.0  2100000       1.0
# 10704              35              4  4400000.0   700000       0.0
# 10708              31              3  3300000.0  1400000       2.0
# 10709              35              7  4000000.0   300000       0.0
# 10711              16              5  3000000.0  2100000       2.0
# 10712              28              5  2900000.0   700000       1.0
# 10713               4              3  2100000.0  1400000       0.0
#
#        Infect_Prob
# 0        49.135010
# 2        73.224000
# 3        48.779225
# 4        87.868800
# 5        49.518345
# 7        49.121025
# 9        48.475097
# 10       46.970339
# 11       45.494822
# 13       48.948107
# 15       47.888912
# 16       51.009536
# 17       47.207078
# 18       48.868666
# 19       50.180430
# 22       77.129280
# 23       46.698926
# 24       41.005440
# 25       48.050225
# 26       51.576403
# 27       49.104399
# 29       49.559846
# 32       49.573003
# 36       51.064198
# 38       46.892097
# 40       47.796265
# 42       46.744646
# 48       47.725811
# 50       44.238657
# 52       47.529497
# ...            ...
# 10672    58.731608
# 10674    91.774080
# 10675    51.103014
# 10676    48.734679
# 10677    53.964442
# 10678    45.780613
# 10679    55.225344
# 10680    53.721942
# 10681    54.339977
# 10682    51.349832
# 10683    53.612072
# 10684    46.681280
# 10685    60.929442
# 10689    54.917978
# 10691    51.148002
# 10693    92.750400
# 10694    45.884754
# 10695    45.595862
# 10696    53.858163
# 10698    54.673920
# 10700    52.927680
# 10701    46.943607
# 10702    53.944690
# 10703    60.658171
# 10704    59.594744
# 10708    53.741750
# 10709    41.981760
# 10711    47.708533
# 10712    53.803565
# 10713    68.342400
#
# [6777 rows x 24 columns]

# %%
# We created X and y columns for training dataset while y column for dataset to predict will
# be generated by our model in final step
X = df_train.drop(["Infect_Prob"], axis=1)
#y = np.log1p(df_train['Infect_prob'])
y = df_train["Infect_Prob"]
X_to_predict = df_to_predict

# %%
X.head()
# Out:
#    Region  Gender  Designation  Married  Children  Occupation  Mode_transport  \
# 0       2       1            1        1       1.0           5               2
# 2       2       1            1        0       1.0           6               2
# 3       2       1            1        1       1.0           2               0
# 4       2       1            1        0       2.0           8               0
# 5       2       1            1        1       1.0           3               2
#
#    cases/1M  Deaths/1M  Age  Coma score Pulmonary score  Diuresis  Platelets  \
# 0         2          0   68           8            <400     441.0      154.0
# 2         2          0   19          13            <300     416.0      124.0
# 3         2          0   33           9            <200     410.0       98.0
# 4         2          0   23           7            <400     390.0       21.0
# 5         2          0   35           9            <100     389.0      139.0
#
#      HBB  d-dimer  Heart rate  HDL cholesterol  Charlson Index  Blood Glucose  \
# 0   93.0    233.0        82.0             58.0              27              7
# 2  137.0    213.0        77.0             43.0              40              6
# 3  167.0    275.0        64.0             60.0              27              7
# 4  153.0    331.0        71.0             64.0              32              7
# 5   86.0    216.0        94.0             38.0               5              5
#
#    Insurance   salary  FT/month
# 0  3600000.0  1300000       2.0
# 2  3400000.0   900000       1.0
# 3   700000.0  2300000       1.0
# 4  3200000.0  1100000       1.0
# 5  4600000.0  1900000       2.0

# %%
#Separate categorical and numerical columns in dataframe
X_categorical = X.select_dtypes(exclude=['int', 'float'])
X_numerical = X.select_dtypes(include=['int', 'float'])

X_to_predict_categorical = X_to_predict.select_dtypes(exclude=['int', 'float'])
X_to_predict_numerical = X_to_predict.select_dtypes(include=['int', 'float'])

# %%
# Check if categorical columns are assigned properly
X_categorical.head()

#Create a back up copy specifically for plotting graphs
X_numerical_graph = X_numerical.copy()
X_categorical_graph = X_categorical.copy()

# %%
#Check if numerical columns are assigned properly
X_categorical.shape
# Out:
# (6777, 8)

# %%
X_numerical.head()
# Out:
#    Region  Gender  Designation  Married  Children  Occupation  Mode_transport  \
# 0       2       1            1        1       1.0           5               2
# 2       2       1            1        0       1.0           6               2
# 3       2       1            1        1       1.0           2               0
# 4       2       1            1        0       2.0           8               0
# 5       2       1            1        1       1.0           3               2
#
#    Diuresis  Platelets    HBB  d-dimer  Heart rate  HDL cholesterol  \
# 0     441.0      154.0   93.0    233.0        82.0             58.0
# 2     416.0      124.0  137.0    213.0        77.0             43.0
# 3     410.0       98.0  167.0    275.0        64.0             60.0
# 4     390.0       21.0  153.0    331.0        71.0             64.0
# 5     389.0      139.0   86.0    216.0        94.0             38.0
#
#    Insurance  FT/month
# 0  3600000.0       2.0
# 2  3400000.0       1.0
# 3   700000.0       1.0
# 4  3200000.0       1.0
# 5  4600000.0       2.0

# %%
X_numerical.shape
# Out:
# (6777, 15)

# %%
#Label encode and hot encode categorical columns
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X_categorical = X_categorical.apply(LabelEncoder().fit_transform)
X_to_predict_categorical = X_to_predict_categorical.apply(LabelEncoder().fit_transform)

# %%
#Check values after label encoding
X_categorical.head()
# Out:
#    cases/1M  Deaths/1M  Age  Coma score  Pulmonary score  Charlson Index  \
# 0         1          0   52           5                3              27
# 2         1          0    3          10                2              40
# 3         1          0   17           6                1              27
# 4         1          0    7           4                3              32
# 5         1          0   19           6                0               5
#
#    Blood Glucose  salary
# 0              4      10
# 2              3       6
# 3              4      20
# 4              4       8
# 5              2      16

# %%
# Check the skew of all numerical features
from scipy.stats import skew
skewed_feats = X_numerical.apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(10)
skewness = skewness[abs(skewness) > 0.75]
print("There are {} skewed numerical features to Box Cox transform".format(skewness.shape[0]))
# Out:
# Skew in numerical features:
#
# There are 15 skewed numerical features to Box Cox transform

# %%
#Merge categorical and numerical columns back into respective X and X_to_predict
X = pd.concat([X_categorical, X_numerical], axis=1)
X_to_predict = pd.concat([X_to_predict_categorical, X_to_predict_numerical], axis=1)

# %%
#Check shape of all three to verify that merge was done properly in above step
print(X.shape, X_numerical.shape, X_categorical.shape)
print(X_to_predict.shape, X_to_predict_numerical.shape, X_to_predict_categorical.shape)
print(y.shape)
# Out:
# (6777, 23) (6777, 15) (6777, 8)
# (14498, 23) (14498, 6) (14498, 17)
# (6777,)

# %%
X_to_predict.shape
# Out:
# (14498, 23)

# %%
X.shape
# Out:
# (6777, 23)

# %%
X.shape
# Out:
# (6777, 23)

# %%
# Define model
model = Sequential()
model.add(Dense(6777, input_dim=23, activation= "relu"))
model.add(Dense(677, activation= "relu"))
model.add(Dense(677, activation= "relu"))
model.add(Dense(1))
model.summary() #Print model Summary
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 6777)              162648
# _________________________________________________________________
# dense_22 (Dense)             (None, 677)               4588706
# _________________________________________________________________
# dense_23 (Dense)             (None, 677)               459006
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 678
# =================================================================
# Total params: 5,211,038
# Trainable params: 5,211,038
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss= "mean_squared_error" , optimizer="adam", metrics=["mean_squared_error"])
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 6777/6777 [==============================] - 29s 4ms/step - loss: 5537337251.9198 - mean_squared_error: 5537337251.9198
# Epoch 2/20
# 6777/6777 [==============================] - 27s 4ms/step - loss: 2146.8120 - mean_squared_error: 2146.8120
# Epoch 3/20
# 6777/6777 [==============================] - 27s 4ms/step - loss: 10313.7007 - mean_squared_error: 10313.7007
# Epoch 4/20
# 6777/6777 [==============================] - 27s 4ms/step - loss: 14906197.1191 - mean_squared_error: 14906197.1191
# Epoch 5/20
# 6777/6777 [==============================] - 27s 4ms/step - loss: 62727.1957 - mean_squared_error: 62727.1957
# Epoch 6/20
# 6777/6777 [==============================] - 27s 4ms/step - loss: 7252.0715 - mean_squared_error: 7252.0715
# Epoch 7/20
# 6777/6777 [==============================] - 27s 4ms/step - loss: 980614.4057 - mean_squared_error: 980614.4057
# Epoch 8/20
# 6777/6777 [==============================] - 27s 4ms/step - loss: 93048235.5539 - mean_squared_error: 93048235.5539
# Epoch 9/20
# 6777/6777 [==============================] - 27s 4ms/step - loss: 717.8426 - mean_squared_error: 717.8426
# Epoch 10/20
# 6777/6777 [==============================] - 27s 4ms/step - loss: 700.6683 - mean_squared_error: 700.6683
# Epoch 11/20
# 6777/6777 [==============================] - 32s 5ms/step - loss: 741.8460 - mean_squared_error: 741.8460
# Epoch 12/20
# 6777/6777 [==============================] - 30s 4ms/step - loss: 698.8619 - mean_squared_error: 698.8619
# Epoch 13/20
# 6777/6777 [==============================] - 36s 5ms/step - loss: 721.1066 - mean_squared_error: 721.1066
# Epoch 14/20
# 6777/6777 [==============================] - 33s 5ms/step - loss: 713.5246 - mean_squared_error: 713.5246
# Epoch 15/20
# 6777/6777 [==============================] - 32s 5ms/step - loss: 725.1539 - mean_squared_error: 725.1539
# Epoch 16/20
# 6777/6777 [==============================] - 31s 5ms/step - loss: 730.9348 - mean_squared_error: 730.9348
# Epoch 17/20
# 6777/6777 [==============================] - 33s 5ms/step - loss: 720.8146 - mean_squared_error: 720.8146
# Epoch 18/20
# 6777/6777 [==============================] - 30s 4ms/step - loss: 776.6610 - mean_squared_error: 776.6610
# Epoch 19/20
# 6777/6777 [==============================] - 31s 5ms/step - loss: 976.9036 - mean_squared_error: 976.9036
# Epoch 20/20
# 6777/6777 [==============================] - 30s 4ms/step - loss: 839.7344 - mean_squared_error: 839.7344

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
import numpy as np
from sklearn.metrics import mean_squared_log_error
pred_train= model.predict_proba(X)
print(np.sqrt(mean_squared_error(y,pred_train)))

pred= model.predict(X_to_predict)
#print(np.sqrt(mean_squared_error(pred,X_to_predict))) 
pred_train=pd.DataFrame(pred)
pred
pred_train
pred_train= model.predict_proba(X)
#y_pred = regressor.predict(X)
print('R Squared(Accuracy)', metrics.r2_score(y,pred_train))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\sequential.py:247: UserWarning: Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
#   warnings.warn('Network returning invalid probability values. '
# 25.50532146353101
# R Squared(Accuracy) -4.350991420508657
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\sequential.py:247: UserWarning: Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
#   warnings.warn('Network returning invalid probability values. '

# %%
X_to_predict.shape
# Out:
# (14498, 23)

# %%
pred.shape
# Out:
# (14498, 1)

# %%
pred_train.shape
# Out:
# (6777, 1)

# %%
X.shape
# Out:
# (6777, 23)

# %%
pred_train
# Out:
# array([[53.153397],
#        [50.191483],
#        [12.676836],
#        ...,
#        [44.219803],
#        [43.07576 ],
#        [31.185503]], dtype=float32)

# %%
pred
# Out:
# array([[ 0.46550655],
#        [ 0.28829578],
#        [-0.2309878 ],
#        ...,
#        [ 0.20073573],
#        [-0.0443203 ],
#        [ 0.21487843]], dtype=float32)
